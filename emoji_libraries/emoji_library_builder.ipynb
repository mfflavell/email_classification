# %% [markdown]
# # Emoji Library Builder
#
# The purpose of this notebook is to build a comprehensive library of emojis with their names and utf-8 as well as unicode code points.
#
# The most comprehensive collection of emojis I've found (care of James Caldwell and ['Barndog'](https://stackoverflow.com/questions/71404081/how-to-obtain-a-full-list-of-unicode-emojis-from-the-unicode-website)) is this [text file developed by Unicode Inc. in 2021.](https://unicode.org/Public/emoji/14.0/emoji-test.txt)
#
# ## Task List
#
# * [X]  Copy and paste the tabular format of the txt file into a new txt file so the intro and headings don't interfere with the dataframe.
# * [X]  Import the updated txt file as a dataframe and remove unnecessary features.
# * [X]  Split the emoji feature into 3 separate features: emoji, emoji number, and description.
# * [X]  Create two more features containing the utf-8 codepoints as bytes object and as string object for each emoji.
# * [X]  Create another feature of cleaned utf-8 code points by removing any "/" for easy matching in other strings.
# * [X]  Create another series of features for unicode representations

# %% [markdown]
# ## Packages

# %%
import pandas as pd

# %% [markdown]
# ## Txt to DataFrame

# %%
df = pd.read_fwf('emoji-test-cleaned.txt')

# %%
df.head(150)
# Out:
#         hex_codepoint Unnamed: 1  ;           status  #  \
# 0               1F600        NaN  ;  fully-qualified  #
# 1               1F603        NaN  ;  fully-qualified  #
# 2               1F604        NaN  ;  fully-qualified  #
# 3               1F601        NaN  ;  fully-qualified  #
# 4               1F606        NaN  ;  fully-qualified  #
# ..                ...        ... ..              ... ..
# 145  2764 FE0F 200D 1        A79  ;  fully-qualified  #
# 146   2764 200D 1FA79        NaN  ;      unqualified  #
# 147         2764 FE0F        NaN  ;  fully-qualified  #
# 148              2764        NaN  ;      unqualified  #
# 149             1F9E1        NaN  ;  fully-qualified  #
#
#                                       emoji Unnamed: 6
# 0                      😀 E1.0 grinning face        NaN
# 1        😃 E0.6 grinning face with big eyes        NaN
# 2    😄 E0.6 grinning face with smiling eyes        NaN
# 3     😁 E0.6 beaming face with smiling eyes        NaN
# 4            😆 E0.6 grinning squinting face        NaN
# ..                                      ...        ...
# 145                ❤️‍🩹 E13.1 mending heart        NaN
# 146                 ❤‍🩹 E13.1 mending heart        NaN
# 147                       ❤️ E0.6 red heart        NaN
# 148                        ❤ E0.6 red heart        NaN
# 149                     🧡 E5.0 orange heart        NaN
#
# [150 rows x 7 columns]

# %% [markdown]
# The initial dataframe is a little messy.  Let's drop unnecessary columns.

# %%
df = df.drop(columns=['Unnamed: 1', ';', '#', 'Unnamed: 6'])

# %%
df.head()
# Out:
#   hex_codepoint           status                                   emoji
# 0         1F600  fully-qualified                    😀 E1.0 grinning face
# 1         1F603  fully-qualified      😃 E0.6 grinning face with big eyes
# 2         1F604  fully-qualified  😄 E0.6 grinning face with smiling eyes
# 3         1F601  fully-qualified   😁 E0.6 beaming face with smiling eyes
# 4         1F606  fully-qualified          😆 E0.6 grinning squinting face

# %% [markdown]
# ## New Features: Emoji, E Version, Description

# %% [markdown]
# And now let's clean up the emoji column by separating out the contents into different columns: emoji, e_version and description.

# %%
df[['emoji', 'e_version', 'description']] = df['emoji'].str.split(' ', 2, expand=True)

# %%
df.head()
# Out:
#   hex_codepoint           status emoji e_version  \
# 0         1F600  fully-qualified     😀      E1.0
# 1         1F603  fully-qualified     😃      E0.6
# 2         1F604  fully-qualified     😄      E0.6
# 3         1F601  fully-qualified     😁      E0.6
# 4         1F606  fully-qualified     😆      E0.6
#
#                        description
# 0                    grinning face
# 1      grinning face with big eyes
# 2  grinning face with smiling eyes
# 3   beaming face with smiling eyes
# 4          grinning squinting face

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4697 entries, 0 to 4696
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   hex_codepoint  4697 non-null   object
#  1   status         4697 non-null   object
#  2   emoji          4697 non-null   object
#  3   e_version      4697 non-null   object
#  4   description    4697 non-null   object
# dtypes: object(5)
# memory usage: 183.6+ KB

# %% [markdown]
# We have a comprehensive library of 4,696 emojis.

# %% [markdown]
# ## New Features: UTF8_Bytes, UTF8_Str, and UTF8_Clean Codepoints

# %% [markdown]
# Now let's test our utf-8 encoding and cleaning process on a single emoji to get it right and then iterate over the entire emoji column to create the new feature for every emoji.

# %% [markdown]
# Emoji

# %%
df.emoji[0]
# Out:
# '😀'

# %% [markdown]
# Bytes object

# %%
test = df.emoji[0].encode('utf-8')
print(test)
# Out:
# b'\xf0\x9f\x98\x80'

# %% [markdown]
# String object

# %%
test = str(test).replace("b'",'')
test = test.replace("'",'')
print(test)
# Out:
# \xf0\x9f\x98\x80

# %% [markdown]
# Cleaned with no "\" or spaces.

# %%
test = test.replace("\\",'')
print(test)
# Out:
# xf0x9fx98x80

# %%
for i in df.index:
    # create the utf8_bytes code point feature in bytes datatype
    df.at[i,'utf8_bytes'] = df.emoji[i].encode('utf-8')
    # create the utf8_str code point feature as string datatype
    df.at[i,'utf8_str'] = str(df.utf8_bytes[i]).replace("b'",'')
    df.at[i,'utf8_str'] = df.utf8_str[i].replace("'",'')
    # create the utf8_cleaned code point feature for easy matching within other strings
    df.at[i,'utf8_clean'] = df.utf8_str[i].replace("\\",'')

# %%
df.head(20)
# Out:
#    hex_codepoint           status emoji e_version  \
# 0          1F600  fully-qualified     😀      E1.0
# 1          1F603  fully-qualified     😃      E0.6
# 2          1F604  fully-qualified     😄      E0.6
# 3          1F601  fully-qualified     😁      E0.6
# 4          1F606  fully-qualified     😆      E0.6
# 5          1F605  fully-qualified     😅      E0.6
# 6          1F923  fully-qualified     🤣      E3.0
# 7          1F602  fully-qualified     😂      E0.6
# 8          1F642  fully-qualified     🙂      E1.0
# 9          1F643  fully-qualified     🙃      E1.0
# 10         1FAE0  fully-qualified     🫠     E14.0
# 11         1F609  fully-qualified     😉      E0.6
# 12         1F60A  fully-qualified     😊      E0.6
# 13         1F607  fully-qualified     😇      E1.0
# 14         1F970  fully-qualified     🥰     E11.0
# 15         1F60D  fully-qualified     😍      E0.6
# 16         1F929  fully-qualified     🤩      E5.0
# 17         1F618  fully-qualified     😘      E0.6
# 18         1F617  fully-qualified     😗      E1.0
# 19     263A FE0F  fully-qualified    ☺️      E0.6
#
#                         description                   utf8_bytes  \
# 0                     grinning face          b'\xf0\x9f\x98\x80'
# 1       grinning face with big eyes          b'\xf0\x9f\x98\x83'
# 2   grinning face with smiling eyes          b'\xf0\x9f\x98\x84'
# 3    beaming face with smiling eyes          b'\xf0\x9f\x98\x81'
# 4           grinning squinting face          b'\xf0\x9f\x98\x86'
# 5          grinning face with sweat          b'\xf0\x9f\x98\x85'
# 6     rolling on the floor laughing          b'\xf0\x9f\xa4\xa3'
# 7            face with tears of joy          b'\xf0\x9f\x98\x82'
# 8             slightly smiling face          b'\xf0\x9f\x99\x82'
# 9                  upside-down face          b'\xf0\x9f\x99\x83'
# 10                     melting face          b'\xf0\x9f\xab\xa0'
# 11                     winking face          b'\xf0\x9f\x98\x89'
# 12   smiling face with smiling eyes          b'\xf0\x9f\x98\x8a'
# 13           smiling face with halo          b'\xf0\x9f\x98\x87'
# 14         smiling face with hearts          b'\xf0\x9f\xa5\xb0'
# 15     smiling face with heart-eyes          b'\xf0\x9f\x98\x8d'
# 16                      star-struck          b'\xf0\x9f\xa4\xa9'
# 17              face blowing a kiss          b'\xf0\x9f\x98\x98'
# 18                     kissing face          b'\xf0\x9f\x98\x97'
# 19                     smiling face  b'\xe2\x98\xba\xef\xb8\x8f'
#
#                     utf8_str          utf8_clean
# 0           \xf0\x9f\x98\x80        xf0x9fx98x80
# 1           \xf0\x9f\x98\x83        xf0x9fx98x83
# 2           \xf0\x9f\x98\x84        xf0x9fx98x84
# 3           \xf0\x9f\x98\x81        xf0x9fx98x81
# 4           \xf0\x9f\x98\x86        xf0x9fx98x86
# 5           \xf0\x9f\x98\x85        xf0x9fx98x85
# 6           \xf0\x9f\xa4\xa3        xf0x9fxa4xa3
# 7           \xf0\x9f\x98\x82        xf0x9fx98x82
# 8           \xf0\x9f\x99\x82        xf0x9fx99x82
# 9           \xf0\x9f\x99\x83        xf0x9fx99x83
# 10          \xf0\x9f\xab\xa0        xf0x9fxabxa0
# 11          \xf0\x9f\x98\x89        xf0x9fx98x89
# 12          \xf0\x9f\x98\x8a        xf0x9fx98x8a
# 13          \xf0\x9f\x98\x87        xf0x9fx98x87
# 14          \xf0\x9f\xa5\xb0        xf0x9fxa5xb0
# 15          \xf0\x9f\x98\x8d        xf0x9fx98x8d
# 16          \xf0\x9f\xa4\xa9        xf0x9fxa4xa9
# 17          \xf0\x9f\x98\x98        xf0x9fx98x98
# 18          \xf0\x9f\x98\x97        xf0x9fx98x97
# 19  \xe2\x98\xba\xef\xb8\x8f  xe2x98xbaxefxb8x8f

# %%
df.tail(20)
# Out:
#          hex_codepoint           status    emoji e_version  \
# 4677       1F1FA 1F1FE  fully-qualified       🇺🇾      E2.0
# 4678       1F1FA 1F1FF  fully-qualified       🇺🇿      E2.0
# 4679       1F1FB 1F1E6  fully-qualified       🇻🇦      E2.0
# 4680       1F1FB 1F1E8  fully-qualified       🇻🇨      E2.0
# 4681       1F1FB 1F1EA  fully-qualified       🇻🇪      E2.0
# 4682       1F1FB 1F1EC  fully-qualified       🇻🇬      E2.0
# 4683       1F1FB 1F1EE  fully-qualified       🇻🇮      E2.0
# 4684       1F1FB 1F1F3  fully-qualified       🇻🇳      E2.0
# 4685       1F1FB 1F1FA  fully-qualified       🇻🇺      E2.0
# 4686       1F1FC 1F1EB  fully-qualified       🇼🇫      E2.0
# 4687       1F1FC 1F1F8  fully-qualified       🇼🇸      E2.0
# 4688       1F1FD 1F1F0  fully-qualified       🇽🇰      E2.0
# 4689       1F1FE 1F1EA  fully-qualified       🇾🇪      E2.0
# 4690       1F1FE 1F1F9  fully-qualified       🇾🇹      E2.0
# 4691       1F1FF 1F1E6  fully-qualified       🇿🇦      E2.0
# 4692       1F1FF 1F1F2  fully-qualified       🇿🇲      E2.0
# 4693       1F1FF 1F1FC  fully-qualified       🇿🇼      E2.0
# 4694  1F3F4 E0067 E006  fully-qualified  🏴󠁧󠁢󠁥󠁮󠁧󠁿      E5.0
# 4695  1F3F4 E0067 E006  fully-qualified  🏴󠁧󠁢󠁳󠁣󠁴󠁿      E5.0
# 4696  1F3F4 E0067 E006  fully-qualified  🏴󠁧󠁢󠁷󠁬󠁳󠁿      E5.0
#
#                          description  \
# 4677                   flag: Uruguay
# 4678                flag: Uzbekistan
# 4679              flag: Vatican City
# 4680  flag: St. Vincent & Grenadines
# 4681                 flag: Venezuela
# 4682    flag: British Virgin Islands
# 4683       flag: U.S. Virgin Islands
# 4684                   flag: Vietnam
# 4685                   flag: Vanuatu
# 4686           flag: Wallis & Futuna
# 4687                     flag: Samoa
# 4688                    flag: Kosovo
# 4689                     flag: Yemen
# 4690                   flag: Mayotte
# 4691              flag: South Africa
# 4692                    flag: Zambia
# 4693                  flag: Zimbabwe
# 4694                   flag: England
# 4695                  flag: Scotland
# 4696                     flag: Wales
#
#                                              utf8_bytes  \
# 4677                b'\xf0\x9f\x87\xba\xf0\x9f\x87\xbe'
# 4678                b'\xf0\x9f\x87\xba\xf0\x9f\x87\xbf'
# 4679                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xa6'
# 4680                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xa8'
# 4681                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xaa'
# 4682                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xac'
# 4683                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xae'
# 4684                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xb3'
# 4685                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xba'
# 4686                b'\xf0\x9f\x87\xbc\xf0\x9f\x87\xab'
# 4687                b'\xf0\x9f\x87\xbc\xf0\x9f\x87\xb8'
# 4688                b'\xf0\x9f\x87\xbd\xf0\x9f\x87\xb0'
# 4689                b'\xf0\x9f\x87\xbe\xf0\x9f\x87\xaa'
# 4690                b'\xf0\x9f\x87\xbe\xf0\x9f\x87\xb9'
# 4691                b'\xf0\x9f\x87\xbf\xf0\x9f\x87\xa6'
# 4692                b'\xf0\x9f\x87\xbf\xf0\x9f\x87\xb2'
# 4693                b'\xf0\x9f\x87\xbf\xf0\x9f\x87\xbc'
# 4694  b'\xf0\x9f\x8f\xb4\xf3\xa0\x81\xa7\xf3\xa0\x81...
# 4695  b'\xf0\x9f\x8f\xb4\xf3\xa0\x81\xa7\xf3\xa0\x81...
# 4696  b'\xf0\x9f\x8f\xb4\xf3\xa0\x81\xa7\xf3\xa0\x81...
#
#                                                utf8_str  \
# 4677                   \xf0\x9f\x87\xba\xf0\x9f\x87\xbe
# 4678                   \xf0\x9f\x87\xba\xf0\x9f\x87\xbf
# 4679                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xa6
# 4680                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xa8
# 4681                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xaa
# 4682                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xac
# 4683                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xae
# 4684                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xb3
# 4685                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xba
# 4686                    \xf0\x9f\x87\xbc\xf0\x9f\x87\xa
# 4687                   \xf0\x9f\x87\xbc\xf0\x9f\x87\xb8
# 4688                   \xf0\x9f\x87\xbd\xf0\x9f\x87\xb0
# 4689                   \xf0\x9f\x87\xbe\xf0\x9f\x87\xaa
# 4690                   \xf0\x9f\x87\xbe\xf0\x9f\x87\xb9
# 4691                   \xf0\x9f\x87\xbf\xf0\x9f\x87\xa6
# 4692                   \xf0\x9f\x87\xbf\xf0\x9f\x87\xb2
# 4693                   \xf0\x9f\x87\xbf\xf0\x9f\x87\xbc
# 4694  \xf0\x9f\x8f\xb4\xf3\xa0\x81\xa7\xf3\xa0\x81\x...
# 4695  \xf0\x9f\x8f\xb4\xf3\xa0\x81\xa7\xf3\xa0\x81\x...
# 4696  \xf0\x9f\x8f\xb4\xf3\xa0\x81\xa7\xf3\xa0\x81\x...
#
#                                              utf8_clean
# 4677                           xf0x9fx87xbaxf0x9fx87xbe
# 4678                           xf0x9fx87xbaxf0x9fx87xbf
# 4679                           xf0x9fx87xbbxf0x9fx87xa6
# 4680                           xf0x9fx87xbbxf0x9fx87xa8
# 4681                           xf0x9fx87xbbxf0x9fx87xaa
# 4682                           xf0x9fx87xbbxf0x9fx87xac
# 4683                           xf0x9fx87xbbxf0x9fx87xae
# 4684                           xf0x9fx87xbbxf0x9fx87xb3
# 4685                           xf0x9fx87xbbxf0x9fx87xba
# 4686                            xf0x9fx87xbcxf0x9fx87xa
# 4687                           xf0x9fx87xbcxf0x9fx87xb8
# 4688                           xf0x9fx87xbdxf0x9fx87xb0
# 4689                           xf0x9fx87xbexf0x9fx87xaa
# 4690                           xf0x9fx87xbexf0x9fx87xb9
# 4691                           xf0x9fx87xbfxf0x9fx87xa6
# 4692                           xf0x9fx87xbfxf0x9fx87xb2
# 4693                           xf0x9fx87xbfxf0x9fx87xbc
# 4694  xf0x9fx8fxb4xf3xa0x81xa7xf3xa0x81xa2xf3xa0x81x...
# 4695  xf0x9fx8fxb4xf3xa0x81xa7xf3xa0x81xa2xf3xa0x81x...
# 4696  xf0x9fx8fxb4xf3xa0x81xa7xf3xa0x81xa2xf3xa0x81x...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4697 entries, 0 to 4696
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   hex_codepoint  4697 non-null   object
#  1   status         4697 non-null   object
#  2   emoji          4697 non-null   object
#  3   e_version      4697 non-null   object
#  4   description    4697 non-null   object
#  5   utf8_bytes     4697 non-null   object
#  6   utf8_str       4697 non-null   object
#  7   utf8_clean     4697 non-null   object
# dtypes: object(8)
# memory usage: 293.7+ KB

# %% [markdown]
# ## New Features: Unicode

# %% [markdown]
# We repeat to do the same for the unicode representation.

# %% [markdown]
# Emoji

# %%
df.emoji[0]
# Out:
# '😀'

# %% [markdown]
# Bytes object

# %%
test = df.emoji[0].encode('unicode_escape')
print(test)
# Out:
# b'\\U0001f600'

# %% [markdown]
# String object

# %%
test = str(test).replace("b'",'')
test = test.replace("'",'')

print(test)
# Out:
# \\U0001f600

# %% [markdown]
# Traditional format

# %%
test = test.replace("000",'+')
print(test)
# Out:
# \\U+1f600

# %%
for i in df.index:
    # create the unicode_bytes code point feature in bytes datatype
    df.at[i,'unicode_bytes'] = df.emoji[i].encode('unicode_escape')
    # create the unicode_str code point feature as string datatype
    df.at[i,'unicode_str'] = str(df.unicode_bytes[i]).replace("b'",'')
    df.at[i,'unicode_str'] = df.unicode_str[i].replace("'",'')

# %%
df.head()
# Out:
#   hex_codepoint           status emoji e_version  \
# 0         1F600  fully-qualified     😀      E1.0
# 1         1F603  fully-qualified     😃      E0.6
# 2         1F604  fully-qualified     😄      E0.6
# 3         1F601  fully-qualified     😁      E0.6
# 4         1F606  fully-qualified     😆      E0.6
#
#                        description           utf8_bytes          utf8_str  \
# 0                    grinning face  b'\xf0\x9f\x98\x80'  \xf0\x9f\x98\x80
# 1      grinning face with big eyes  b'\xf0\x9f\x98\x83'  \xf0\x9f\x98\x83
# 2  grinning face with smiling eyes  b'\xf0\x9f\x98\x84'  \xf0\x9f\x98\x84
# 3   beaming face with smiling eyes  b'\xf0\x9f\x98\x81'  \xf0\x9f\x98\x81
# 4          grinning squinting face  b'\xf0\x9f\x98\x86'  \xf0\x9f\x98\x86
#
#      utf8_clean   unicode_bytes  unicode_str
# 0  xf0x9fx98x80  b'\\U0001f600'  \\U0001f600
# 1  xf0x9fx98x83  b'\\U0001f603'  \\U0001f603
# 2  xf0x9fx98x84  b'\\U0001f604'  \\U0001f604
# 3  xf0x9fx98x81  b'\\U0001f601'  \\U0001f601
# 4  xf0x9fx98x86  b'\\U0001f606'  \\U0001f606

# %%
df.tail(20)
# Out:
#          hex_codepoint           status    emoji e_version  \
# 4677       1F1FA 1F1FE  fully-qualified       🇺🇾      E2.0
# 4678       1F1FA 1F1FF  fully-qualified       🇺🇿      E2.0
# 4679       1F1FB 1F1E6  fully-qualified       🇻🇦      E2.0
# 4680       1F1FB 1F1E8  fully-qualified       🇻🇨      E2.0
# 4681       1F1FB 1F1EA  fully-qualified       🇻🇪      E2.0
# 4682       1F1FB 1F1EC  fully-qualified       🇻🇬      E2.0
# 4683       1F1FB 1F1EE  fully-qualified       🇻🇮      E2.0
# 4684       1F1FB 1F1F3  fully-qualified       🇻🇳      E2.0
# 4685       1F1FB 1F1FA  fully-qualified       🇻🇺      E2.0
# 4686       1F1FC 1F1EB  fully-qualified       🇼🇫      E2.0
# 4687       1F1FC 1F1F8  fully-qualified       🇼🇸      E2.0
# 4688       1F1FD 1F1F0  fully-qualified       🇽🇰      E2.0
# 4689       1F1FE 1F1EA  fully-qualified       🇾🇪      E2.0
# 4690       1F1FE 1F1F9  fully-qualified       🇾🇹      E2.0
# 4691       1F1FF 1F1E6  fully-qualified       🇿🇦      E2.0
# 4692       1F1FF 1F1F2  fully-qualified       🇿🇲      E2.0
# 4693       1F1FF 1F1FC  fully-qualified       🇿🇼      E2.0
# 4694  1F3F4 E0067 E006  fully-qualified  🏴󠁧󠁢󠁥󠁮󠁧󠁿      E5.0
# 4695  1F3F4 E0067 E006  fully-qualified  🏴󠁧󠁢󠁳󠁣󠁴󠁿      E5.0
# 4696  1F3F4 E0067 E006  fully-qualified  🏴󠁧󠁢󠁷󠁬󠁳󠁿      E5.0
#
#                          description  \
# 4677                   flag: Uruguay
# 4678                flag: Uzbekistan
# 4679              flag: Vatican City
# 4680  flag: St. Vincent & Grenadines
# 4681                 flag: Venezuela
# 4682    flag: British Virgin Islands
# 4683       flag: U.S. Virgin Islands
# 4684                   flag: Vietnam
# 4685                   flag: Vanuatu
# 4686           flag: Wallis & Futuna
# 4687                     flag: Samoa
# 4688                    flag: Kosovo
# 4689                     flag: Yemen
# 4690                   flag: Mayotte
# 4691              flag: South Africa
# 4692                    flag: Zambia
# 4693                  flag: Zimbabwe
# 4694                   flag: England
# 4695                  flag: Scotland
# 4696                     flag: Wales
#
#                                              utf8_bytes  \
# 4677                b'\xf0\x9f\x87\xba\xf0\x9f\x87\xbe'
# 4678                b'\xf0\x9f\x87\xba\xf0\x9f\x87\xbf'
# 4679                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xa6'
# 4680                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xa8'
# 4681                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xaa'
# 4682                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xac'
# 4683                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xae'
# 4684                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xb3'
# 4685                b'\xf0\x9f\x87\xbb\xf0\x9f\x87\xba'
# 4686                b'\xf0\x9f\x87\xbc\xf0\x9f\x87\xab'
# 4687                b'\xf0\x9f\x87\xbc\xf0\x9f\x87\xb8'
# 4688                b'\xf0\x9f\x87\xbd\xf0\x9f\x87\xb0'
# 4689                b'\xf0\x9f\x87\xbe\xf0\x9f\x87\xaa'
# 4690                b'\xf0\x9f\x87\xbe\xf0\x9f\x87\xb9'
# 4691                b'\xf0\x9f\x87\xbf\xf0\x9f\x87\xa6'
# 4692                b'\xf0\x9f\x87\xbf\xf0\x9f\x87\xb2'
# 4693                b'\xf0\x9f\x87\xbf\xf0\x9f\x87\xbc'
# 4694  b'\xf0\x9f\x8f\xb4\xf3\xa0\x81\xa7\xf3\xa0\x81...
# 4695  b'\xf0\x9f\x8f\xb4\xf3\xa0\x81\xa7\xf3\xa0\x81...
# 4696  b'\xf0\x9f\x8f\xb4\xf3\xa0\x81\xa7\xf3\xa0\x81...
#
#                                                utf8_str  \
# 4677                   \xf0\x9f\x87\xba\xf0\x9f\x87\xbe
# 4678                   \xf0\x9f\x87\xba\xf0\x9f\x87\xbf
# 4679                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xa6
# 4680                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xa8
# 4681                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xaa
# 4682                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xac
# 4683                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xae
# 4684                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xb3
# 4685                   \xf0\x9f\x87\xbb\xf0\x9f\x87\xba
# 4686                    \xf0\x9f\x87\xbc\xf0\x9f\x87\xa
# 4687                   \xf0\x9f\x87\xbc\xf0\x9f\x87\xb8
# 4688                   \xf0\x9f\x87\xbd\xf0\x9f\x87\xb0
# 4689                   \xf0\x9f\x87\xbe\xf0\x9f\x87\xaa
# 4690                   \xf0\x9f\x87\xbe\xf0\x9f\x87\xb9
# 4691                   \xf0\x9f\x87\xbf\xf0\x9f\x87\xa6
# 4692                   \xf0\x9f\x87\xbf\xf0\x9f\x87\xb2
# 4693                   \xf0\x9f\x87\xbf\xf0\x9f\x87\xbc
# 4694  \xf0\x9f\x8f\xb4\xf3\xa0\x81\xa7\xf3\xa0\x81\x...
# 4695  \xf0\x9f\x8f\xb4\xf3\xa0\x81\xa7\xf3\xa0\x81\x...
# 4696  \xf0\x9f\x8f\xb4\xf3\xa0\x81\xa7\xf3\xa0\x81\x...
#
#                                              utf8_clean  \
# 4677                           xf0x9fx87xbaxf0x9fx87xbe
# 4678                           xf0x9fx87xbaxf0x9fx87xbf
# 4679                           xf0x9fx87xbbxf0x9fx87xa6
# 4680                           xf0x9fx87xbbxf0x9fx87xa8
# 4681                           xf0x9fx87xbbxf0x9fx87xaa
# 4682                           xf0x9fx87xbbxf0x9fx87xac
# 4683                           xf0x9fx87xbbxf0x9fx87xae
# 4684                           xf0x9fx87xbbxf0x9fx87xb3
# 4685                           xf0x9fx87xbbxf0x9fx87xba
# 4686                            xf0x9fx87xbcxf0x9fx87xa
# 4687                           xf0x9fx87xbcxf0x9fx87xb8
# 4688                           xf0x9fx87xbdxf0x9fx87xb0
# 4689                           xf0x9fx87xbexf0x9fx87xaa
# 4690                           xf0x9fx87xbexf0x9fx87xb9
# 4691                           xf0x9fx87xbfxf0x9fx87xa6
# 4692                           xf0x9fx87xbfxf0x9fx87xb2
# 4693                           xf0x9fx87xbfxf0x9fx87xbc
# 4694  xf0x9fx8fxb4xf3xa0x81xa7xf3xa0x81xa2xf3xa0x81x...
# 4695  xf0x9fx8fxb4xf3xa0x81xa7xf3xa0x81xa2xf3xa0x81x...
# 4696  xf0x9fx8fxb4xf3xa0x81xa7xf3xa0x81xa2xf3xa0x81x...
#
#                                           unicode_bytes  \
# 4677                          b'\\U0001f1fa\\U0001f1fe'
# 4678                          b'\\U0001f1fa\\U0001f1ff'
# 4679                          b'\\U0001f1fb\\U0001f1e6'
# 4680                          b'\\U0001f1fb\\U0001f1e8'
# 4681                          b'\\U0001f1fb\\U0001f1ea'
# 4682                          b'\\U0001f1fb\\U0001f1ec'
# 4683                          b'\\U0001f1fb\\U0001f1ee'
# 4684                          b'\\U0001f1fb\\U0001f1f3'
# 4685                          b'\\U0001f1fb\\U0001f1fa'
# 4686                          b'\\U0001f1fc\\U0001f1eb'
# 4687                          b'\\U0001f1fc\\U0001f1f8'
# 4688                          b'\\U0001f1fd\\U0001f1f0'
# 4689                          b'\\U0001f1fe\\U0001f1ea'
# 4690                          b'\\U0001f1fe\\U0001f1f9'
# 4691                          b'\\U0001f1ff\\U0001f1e6'
# 4692                          b'\\U0001f1ff\\U0001f1f2'
# 4693                          b'\\U0001f1ff\\U0001f1fc'
# 4694  b'\\U0001f3f4\\U000e0067\\U000e0062\\U000e0065...
# 4695  b'\\U0001f3f4\\U000e0067\\U000e0062\\U000e0073...
# 4696  b'\\U0001f3f4\\U000e0067\\U000e0062\\U000e0077...
#
#                                             unicode_str
# 4677                             \\U0001f1fa\\U0001f1fe
# 4678                             \\U0001f1fa\\U0001f1ff
# 4679                             \\U0001f1fb\\U0001f1e6
# 4680                             \\U0001f1fb\\U0001f1e8
# 4681                             \\U0001f1fb\\U0001f1ea
# 4682                             \\U0001f1fb\\U0001f1ec
# 4683                             \\U0001f1fb\\U0001f1ee
# 4684                             \\U0001f1fb\\U0001f1f3
# 4685                             \\U0001f1fb\\U0001f1fa
# 4686                              \\U0001f1fc\\U0001f1e
# 4687                             \\U0001f1fc\\U0001f1f8
# 4688                             \\U0001f1fd\\U0001f1f0
# 4689                             \\U0001f1fe\\U0001f1ea
# 4690                             \\U0001f1fe\\U0001f1f9
# 4691                             \\U0001f1ff\\U0001f1e6
# 4692                             \\U0001f1ff\\U0001f1f2
# 4693                             \\U0001f1ff\\U0001f1fc
# 4694  \\U0001f3f4\\U000e0067\\U000e0062\\U000e0065\\...
# 4695  \\U0001f3f4\\U000e0067\\U000e0062\\U000e0073\\...
# 4696  \\U0001f3f4\\U000e0067\\U000e0062\\U000e0077\\...

# %% [markdown]
# Save completed library to our local directory and we can start using it in our other programs.

# %%
df.to_csv("emoji_lib_expanded.csv", index = False)

# %% [markdown]
# ## Side Notes

# %% [markdown]
# I'm not confident about the format of the unicodes because to actually print an emoji using these codes you need one \ instead of two \\.  I'm having a hard time getting python to recognize that I need only one \ because the \ character is a special escape operator.  But because my primary need is the utf-8 codepoints, which are in the right format, I will leave this problem for another day when it's necessary to solve.

# %%
'🏴󠁧󠁢󠁷󠁬󠁳󠁿'.encode('unicode_escape')
# Out:
# b'\\U0001f3f4\\U000e0067\\U000e0062\\U000e0077\\U000e006c\\U000e0073\\U000e007f'

# %%
print('\\U0001f3f4\\U000e0067\\U000e0062\\U000e0077\\U000e006c\\U000e0073\\U000e007f')
# Out:
# \U0001f3f4\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f

# %%
print('\U0001f3f4\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f')
# Out:
# 🏴󠁧󠁢󠁷󠁬󠁳󠁿

# %%
print('\U0001F5FD')
# Out:
# 🗽
